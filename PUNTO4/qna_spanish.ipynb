# %%
## Punto 4 - Fine Tunning

# %%
import json

# %%
do_fine_tuning = False

lang = "spanish"

#HPC calculated files
input_encodings_file = f"data_hpc/{lang}/train_encoding_{lang}.pkl"
output_model_file = f"data_hpc/{lang}/model_post_tunning_{lang}.pkl"

#Models path
model_folder_path = f'models/{lang}/qna_english_custom'

#Dataset
dataset_path = f"qna_database/{lang}/{lang}.json"

# %%
contexts = []
questions = []
answers = []

with open(dataset_path, "r") as file:
    for line in file:
        doc = json.loads(line)
        #print(doc)
        #print(doc["context"])
        contexts.append(doc["context"])
        answers.append(doc["answer"])
        questions.append(doc["question"])

print(f"Contextos {str(len(contexts))}, Preguntas {str(len(questions))}, Respuestas {str(len(answers))}")
# Out:
# Contextos 926, Preguntas 926, Respuestas 926
# 'Mantenimiento del virus del Ébola: si no son (solo) murciélagos, ¿qué más?\n\nhttps://www.ncbi.nlm.nih.gov/pmc/articles/PMC6213544/\n\nSHA: f16da7cf7a952fb981dfc0d77280aac9c3ab933a\n\nAutores: Caron, Alexandre; Bourgarel, Mathieu; Cappelle, Julien; Liégeois, Florian; De Nys, Hélène M .; Roger, François\nFecha: 2018-10-09\nDOI: 10.3390 / v10100549\nLicencia: cc-by\n\nResumen: Los mecanismos de mantenimiento de los ebolavirus en los ecosistemas forestales africanos aún se desconocen, pero evidencias indirectas apuntan a la participación de algunas especies de murciélagos. A pesar de una intensa investigación, la principal hipótesis del mantenimiento de los murciélagos aún no se ha confirmado. Las hipótesis alternativas de un anfitrión de mantenimiento que no sea de murciélagos o una comunidad de mantenimiento que incluya, o no, varios murciélagos y otras especies, merecen más investigación. Sin embargo, los ecosistemas forestales africanos albergan una gran diversidad biológica y abundan en posibles hospedadores de mantenimiento. ¿Cómo se descifra uno? Dado que estudios recientes han revelado que varias especies de murciélagos han estado expuestas a los ebolavirus, el denominador común de estas hipótesis es que, dentro del ciclo epidemiológico, algunas especies de murciélagos deben estar expuestas a los virus e infectadas por estos posibles huéspedes alternativos. Bajo esta restricción, y dada la peculiar ecología de los murciélagos (comportamiento de percha, utilización del hábitat y modo de vuelo), revisamos los hospedadores y las vías de transmisión que pueden conducir a la exposición de los murciélagos y la infección a los ebolavirus. En contraste con la capacidad de los murciélagos para transmitir ebolavirus y otros patógenos a muchos huéspedes, nuestros resultados indican que solo un número limitado de huéspedes y vías pueden conducir a la transmisión de ebolavirus a los murciélagos, y que el huésped de mantenimiento alternativo, si existe, debe estar entre ellos. Se proporciona una lista de estas vías, junto con protocolos para priorizar e investigar estas hipótesis alternativas. En conclusión, tener en cuenta la ecología de los murciélagos y su conocida participación en la ecología de los ebolavirus reduce drásticamente la lista de posibles huéspedes de mantenimiento alternativos para los ebolavirus. Comprender la historia natural de los ebolavirus es una prioridad de salud, e investigar estas hipótesis alternativas podría completar el esfuerzo actual centrado en el papel de los murciélagos.\n\nTexto: Ebolavirus (EBV), según Kuhn et al. clasificación [1]) son filovirus de ARN monocatenario que pueden inducir una alta mortalidad en algunos huéspedes, incluidos los simios y los seres humanos [2, 3]. Los diferentes ebolavirus han causado brotes humanos localizados pero dramáticos, principalmente en África Central, en los últimos 40 años. El reciente brote de África Occidental en 2013-2016 dio un resumen del potencial pandémico de estos patógenos [4, 5].\n\nDesenredar la complejidad de los hospedadores o comunidades de mantenimiento en sistemas de hospedadores múltiples en la interfaz vida silvestre / ganado / ser humano es una tarea difícil [16] [17] [18]. El mantenimiento del VEB en los bosques ecuatoriales aún no se comprende. Algunas especies de mamíferos desempeñaron un papel importante en el desencadenamiento de brotes en humanos: simios como los chimpancés (Pan troglodytes troglodytes y P. t. Verus) y los gorilas de las tierras bajas occidentales (Gorilla gorilla gorilla) estuvieron en el origen de varios brotes en humanos [10] [11] [12], pero se ha encontrado que son altamente susceptibles al VEB con un potencial impacto drástico para sus poblaciones [12, 19]. También se han encontrado canales de duiker (Cephalophus sp.) Positivas para EBOV PCR [20]. Uno no esperaría una mortalidad tan alta (en relación con su densidad de población) de EBOV en hospedadores de mantenimiento. Sin embargo, estos datos indican su posibl ...
